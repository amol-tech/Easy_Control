# %%
import json
import os
from json_flatten import flatten
import pandas as pd
import uuid
import jmespath

dir_workspace = os.path.join(os.getcwd(),'workspace_json_to_dataframe')

# %%
# Helper method to add list object in child data list by creating id reference
def add_to_child_data_list(id_val,parent,child,list_data,list_child_data_dict):
    dict_id = {}
    dict_id['ID'] = id_val
    dict_id['PARENT'] = parent
    dict_id['CHILD'] = child
    dict_id['DATA'] = list_data
    list_child_data_dict.append(dict_id)

# %%
# Helper method to remove list object from given dictionary recursively and add it into child data list
def remove_list_and_inject_pk(dict_data,parent,id_val,list_child_data_dict):
    for key in dict_data.keys():
        if isinstance(dict_data[key],list):
            # Removing list and injecting ID value at same place
            list_x = dict_data[key]
            dict_data[key] = id_val
            add_to_child_data_list(id_val,parent,key,list_x,list_child_data_dict)
            
            # Recursion
            for dict_child in list_x:
                remove_list_and_inject_pk(dict_child,key,'#ID#'+str(uuid.uuid1()),list_child_data_dict)
        
        elif isinstance(dict_data[key],dict):
            remove_list_and_inject_pk(dict_data[key],parent,id_val,list_child_data_dict)

# %%
# Helper method to process list of dictionary object and assign PK and FK
def process_list(list_data,pk_col,fk_col=None,fk_col_id=None):
    list_data_in = [flatten(d) for d in list_data]
    list_data_out = []
    for dict_in in list_data_in:
        dict_out = {}
        for key in dict_in:
            if '#ID#' in dict_in[key]:
                dict_out[pk_col] = dict_in[key]
            else:
                #dict_out[key] = dict_in[key]
                dict_out[key[key.rfind('.')+1:]] = dict_in[key]
        if(fk_col != None and fk_col_id != None):
            dict_out[fk_col] = fk_col_id
        list_data_out.append(dict_out)
    return list_data_out

# %%
# Helper method to create internal ID column for join operation which will be dropped finally
def get_col_name(elm_name):
    return elm_name.upper()+'_ID_DROP'

# %%
# Helper method to return filtered json object by jmes path
def get_filter_json(json,instruc_set):
    expression = jmespath.compile(instruc_set)
    return expression.search(json)[0]

# %%
# Helper method to merge multiple list which having element name
def process_child_data_list(list_child_data_dict,dict_final_child_data):
    for dict_x in list_child_data_dict:
        child_key = dict_x['PARENT']+'.'+dict_x['CHILD']
        if(child_key in dict_final_child_data):
            list_existing = dict_final_child_data[child_key]['DATA']
            list_out = process_list(dict_x['DATA'],get_col_name(dict_x['CHILD']),get_col_name(dict_x['PARENT']),dict_x['ID'])
            list_existing.extend(list_out)
        else:
            dict_attr = {}
            list_out = process_list(dict_x['DATA'],get_col_name(dict_x['CHILD']),get_col_name(dict_x['PARENT']),dict_x['ID'])
            dict_attr['DATA'] = list_out
            dict_attr['FK_COL'] = get_col_name(dict_x['PARENT'])
            dict_final_child_data[child_key] = dict_attr

# %%
# !! Unused methods
def get_filter_set(dict_group,filter_list):
    list_final = []
    for df_name in filter_list:
        list_inner = []
        add_hierarchy(dict_group,list_inner,df_name)
        list_final.extend(list_inner)
    return set(list_final)

def add_hierarchy(dict_group,list_parent,child):
    if (child in dict_group):
        list_parent.append(child)
        if dict_group[child] != 'Root':
            add_hierarchy(dict_group,list_parent,dict_group[child])

# %%
# Main method which will return datafrome for given json_data object
def json_to_dataframe(json_data, instruction_set=None, merge=True, drop_id_col=True, debug=False, filter_path=None):
    list_child_data_dict = []
    dict_final_child_data = {}

    if (instruction_set != None):
        expression = jmespath.compile(instruction_set)
        json_data = expression.search(json_data)
        with open('debug.json', 'w') as fp:
            json.dump(json_data, fp)
        

    # Step 0 : Prepare the root list from input json_data
    if isinstance(json_data, dict):
        if len(json_data) == 1 and isinstance(json_data.get(list(json_data.keys())[0]), list):
            list_root = json_data.get(list(json_data.keys())[0])
        else:
            list_root = []
            list_root.append(json_data)
    elif isinstance(json_data, list):
        list_root = json_data
    else:
        print('Exception')

    # Step 1 : Remove list data element from dict and inject primary key id
    for dict_root in list_root:
        remove_list_and_inject_pk(dict_root, 'Root', '#ID#' + str(uuid.uuid1()), list_child_data_dict)

    # Step 2 : process root list
    data_root_out = process_list(list_root, get_col_name('Root'))

    # Step 3 : process child list
    process_child_data_list(list_child_data_dict, dict_final_child_data)

    # Step 4 : Dataframe Creation
    df_root = pd.DataFrame(data_root_out)
    df_final = df_root

    dict_all = {}
    dict_all['root'] = df_root

    # To remove duplicate list data if they have found under different parent
    if(len(list_child_data_dict) > 0):
        df_debug = pd.DataFrame(list_child_data_dict)
        df_group = df_debug[['PARENT', 'CHILD']].drop_duplicates()
        filter_path = 'Root.'+filter_path if filter_path != None else None
        filter_list = [key for key in dict_final_child_data if filter_path == None or key in filter_path]
        
    # Merging of datagroup
    for key in dict_final_child_data:
        df_child = pd.DataFrame(dict_final_child_data[key]['DATA'])
        dict_all[key] = df_child
        if (merge and key in filter_list):
            df_final = pd.merge(df_final, df_child, how='left', left_on=dict_final_child_data[key]['FK_COL'],
                                right_on=dict_final_child_data[key]['FK_COL'])

    # Add meta dataframe for debug purpose
    if (debug):
        df_debug = pd.DataFrame(list_child_data_dict)
        dict_all['meta-debug'] = df_debug
        dict_all['meta-group'] = df_group

    if (drop_id_col):
        cols_to_drop = [c for c in list(df_final.columns) if '_ID_DROP' in c]
        df_final.drop(cols_to_drop, axis=1, inplace=True)

    return df_final, dict_all

# %%
from copy import deepcopy

# Price Example
with open(os.path.join(dir_workspace,'data.json')) as f:
    json_data = json.load(f)

#instruc_set= 'Entities[].QuantLibCurveSurface.IssueCurveAndSurfaceCharacteristics..{Output : IssueCurveAndSurfaceCharacteristics}'
filter_path= 'IssueCurveAndSurfaceCharacteristics.CalendarParticipant'
json_copy = deepcopy(json_data)
df_result,dict_all = json_to_dataframe(json_copy,filter_path='IssueCurveAndSurfaceCharacteristics')
df_result
# Out:
#             MatrixName MatrixType                 Name PrimaryCurrency  \
# 0  Swap Par Rate Curve   SWAPPRTE  CV_SWAP_PAR_JPY_OIS             JPY
#
#                 ActiveFrom InterpolationMethodName ShortExtrapolationMethod  \
# 0  2016-07-06T12:51:23.000                  LINEAR                     FLAT
#
#   LongExtrapolationMethod CurvePurpose          Description  ...  \
# 0                    FLAT      FORWARD  CV_SWAP_PAR_JPY_OIS  ...
#
#   WeekendStartDateNumber_y WeekendEndDateNumber_y ICSCBusinessDayConvention  \
# 0                        7                      1                 FOLLOWING
#
#   ICSCSpotLagDays$int ICSCPeriodEndConvention ICSCDaysPerYearBasis  \
# 0                   2                    NONE              ACT/360
#
#   ICSCConventionName ICSCDataStatus ICSCConventionLegType  \
# 0              FIXED         ACTIVE              SECONLEG
#
#   ICSCConventionsActiveFrom
# 0   2017-01-01T00:00:00.000
#
# [1 rows x 31 columns]

# %%
df_result2.columns
# Out:
# Index(['MatrixName', 'MatrixType', 'Name', 'PrimaryCurrency', 'ActiveFrom',
#        'InterpolationMethodName', 'ShortExtrapolationMethod',
#        'LongExtrapolationMethod', 'CurvePurpose', 'Description',
#        'UseCurveConventions', 'CalendarID_x', 'CalendarName_x',
#        'WeekendStartDateNumber_x', 'WeekendEndDateNumber_x',
#        'BusinessDayConventionSecondLeg', 'DaysPerYearBasisSecondLeg',
#        'PeriodEndConventionSecondLeg', 'SpotLagDaysSecondLeg$int',
#        'CalendarID_y', 'CalendarName_y', 'WeekendStartDateNumber_y',
#        'WeekendEndDateNumber_y', 'ICSCBusinessDayConvention',
#        'ICSCSpotLagDays$int', 'ICSCPeriodEndConvention',
#        'ICSCDaysPerYearBasis', 'ICSCConventionName', 'ICSCDataStatus',
#        'ICSCConventionLegType', 'ICSCConventionsActiveFrom', 'GregorianDate',
#        'BusinessDateIndicator'],
#       dtype='object')

# %%
dict_all.keys()
# Out:
# dict_keys(['root', 'Root.CurveParticipants', 'Root.IssueCurveAndSurfaceCharacteristics', 'IssueCurveAndSurfaceCharacteristics.CalendarParticipant', 'Root.CalendarParticipant', 'Root.CurveSurfaceParticipants', 'CurveSurfaceParticipants.PriceAttributes', 'PriceAttributes.PriceHistory', 'meta-debug', 'meta-group'])

# %%
dict_all['meta-debug']
# Out:
#                                           ID  \
# 0   #ID#f53d6c14-6125-11eb-9474-40b034439dbc
# 1   #ID#f53d6c14-6125-11eb-9474-40b034439dbc
# 2   #ID#f53d6c25-6125-11eb-b3b5-40b034439dbc
# 3   #ID#f53d6c14-6125-11eb-9474-40b034439dbc
# 4   #ID#f53d6c14-6125-11eb-9474-40b034439dbc
# 5   #ID#f53d6c46-6125-11eb-a33b-40b034439dbc
# 6   #ID#f53d9322-6125-11eb-9590-40b034439dbc
# 7   #ID#f53d9324-6125-11eb-ae89-40b034439dbc
# 8   #ID#f53d9326-6125-11eb-9b86-40b034439dbc
# 9   #ID#f53d9327-6125-11eb-8b33-40b034439dbc
# 10  #ID#f53d9329-6125-11eb-b720-40b034439dbc
# 11  #ID#f53d932b-6125-11eb-b830-40b034439dbc
# 12  #ID#f53d932c-6125-11eb-af31-40b034439dbc
# 13  #ID#f53d932e-6125-11eb-93d9-40b034439dbc
# 14  #ID#f53d9330-6125-11eb-9bea-40b034439dbc
# 15  #ID#f53d9331-6125-11eb-87ca-40b034439dbc
# 16  #ID#f53d9333-6125-11eb-bdde-40b034439dbc
# 17  #ID#f53d9335-6125-11eb-9e6f-40b034439dbc
# 18  #ID#f53d9336-6125-11eb-9748-40b034439dbc
# 19  #ID#f53d9338-6125-11eb-85fd-40b034439dbc
# 20  #ID#f53da0e9-6125-11eb-b576-40b034439dbc
# 21  #ID#f53da0ea-6125-11eb-a5f6-40b034439dbc
# 22  #ID#f53da0ec-6125-11eb-80f7-40b034439dbc
# 23  #ID#f53da0ee-6125-11eb-9621-40b034439dbc
# 24  #ID#f53da0ef-6125-11eb-9bde-40b034439dbc
# 25  #ID#f53da0f1-6125-11eb-9c6d-40b034439dbc
# 26  #ID#f53da0f2-6125-11eb-b6b5-40b034439dbc
# 27  #ID#f53da0f4-6125-11eb-b8fe-40b034439dbc
# 28  #ID#f53da0f5-6125-11eb-b7be-40b034439dbc
# 29  #ID#f53da0f7-6125-11eb-8261-40b034439dbc
# 30  #ID#f53da0f8-6125-11eb-950e-40b034439dbc
# 31  #ID#f53da0fa-6125-11eb-8b99-40b034439dbc
# 32  #ID#f53da0fb-6125-11eb-ae28-40b034439dbc
# 33  #ID#f53da0fd-6125-11eb-b214-40b034439dbc
# 34  #ID#f53da0ff-6125-11eb-a68c-40b034439dbc
# 35  #ID#f53da100-6125-11eb-abbc-40b034439dbc
# 36  #ID#f53da102-6125-11eb-bc3f-40b034439dbc
# 37  #ID#f53da103-6125-11eb-a68c-40b034439dbc
# 38  #ID#f53da105-6125-11eb-b185-40b034439dbc
# 39  #ID#f53da107-6125-11eb-89fd-40b034439dbc
# 40  #ID#f53da108-6125-11eb-b3e9-40b034439dbc
# 41  #ID#f53da10a-6125-11eb-95fa-40b034439dbc
# 42  #ID#f53da10c-6125-11eb-b987-40b034439dbc
# 43  #ID#f53da10d-6125-11eb-bbd1-40b034439dbc
# 44  #ID#f53da10f-6125-11eb-b918-40b034439dbc
# 45  #ID#f53da110-6125-11eb-a61b-40b034439dbc
# 46  #ID#f53dba22-6125-11eb-a142-40b034439dbc
#
#                                  PARENT                                CHILD  \
# 0                                  Root                    CurveParticipants
# 1                                  Root  IssueCurveAndSurfaceCharacteristics
# 2   IssueCurveAndSurfaceCharacteristics                  CalendarParticipant
# 3                                  Root                  CalendarParticipant
# 4                                  Root             CurveSurfaceParticipants
# 5              CurveSurfaceParticipants                      PriceAttributes
# 6                       PriceAttributes                         PriceHistory
# 7                       PriceAttributes                         PriceHistory
# 8              CurveSurfaceParticipants                      PriceAttributes
# 9                       PriceAttributes                         PriceHistory
# 10                      PriceAttributes                         PriceHistory
# 11             CurveSurfaceParticipants                      PriceAttributes
# 12                      PriceAttributes                         PriceHistory
# 13                      PriceAttributes                         PriceHistory
# 14             CurveSurfaceParticipants                      PriceAttributes
# 15                      PriceAttributes                         PriceHistory
# 16                      PriceAttributes                         PriceHistory
# 17             CurveSurfaceParticipants                      PriceAttributes
# 18                      PriceAttributes                         PriceHistory
# 19                      PriceAttributes                         PriceHistory
# 20             CurveSurfaceParticipants                      PriceAttributes
# 21                      PriceAttributes                         PriceHistory
# 22                      PriceAttributes                         PriceHistory
# 23             CurveSurfaceParticipants                      PriceAttributes
# 24                      PriceAttributes                         PriceHistory
# 25             CurveSurfaceParticipants                      PriceAttributes
# 26                      PriceAttributes                         PriceHistory
# 27             CurveSurfaceParticipants                      PriceAttributes
# 28                      PriceAttributes                         PriceHistory
# 29             CurveSurfaceParticipants                      PriceAttributes
# 30                      PriceAttributes                         PriceHistory
# 31             CurveSurfaceParticipants                      PriceAttributes
# 32                      PriceAttributes                         PriceHistory
# 33                      PriceAttributes                         PriceHistory
# 34             CurveSurfaceParticipants                      PriceAttributes
# 35                      PriceAttributes                         PriceHistory
# 36             CurveSurfaceParticipants                      PriceAttributes
# 37                      PriceAttributes                         PriceHistory
# 38                      PriceAttributes                         PriceHistory
# 39             CurveSurfaceParticipants                      PriceAttributes
# 40                      PriceAttributes                         PriceHistory
# 41                      PriceAttributes                         PriceHistory
# 42             CurveSurfaceParticipants                      PriceAttributes
# 43                      PriceAttributes                         PriceHistory
# 44             CurveSurfaceParticipants                      PriceAttributes
# 45                      PriceAttributes                         PriceHistory
# 46                      PriceAttributes                         PriceHistory
#
#                                                  DATA
# 0   [{'Instrument': {'PricingBase': {'InstrumentDe...
# 1   [{'ICSCPrimaryCalendar': {'CalendarDefinition'...
# 2   [{'GregorianDate': '2020-10-29T00:00:00.000', ...
# 3   [{'GregorianDate': '2020-10-29T00:00:00.000', ...
# 4   [{'CurveInstrument': {'QuantLibBase': {'Instru...
# 5   [{'PriceHistory': '#ID#f53d9322-6125-11eb-9590...
# 6   [{'Price': '0.024', 'PriceDate': '2019-01-23T0...
# 7   [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 8   [{'PriceHistory': '#ID#f53d9327-6125-11eb-8b33...
# 9   [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 10  [{'Price': '0.02407', 'PriceDate': '2019-01-23...
# 11  [{'PriceHistory': '#ID#f53d932c-6125-11eb-af31...
# 12  [{'Price': '0.02414', 'PriceDate': '2019-01-23...
# 13  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 14  [{'PriceHistory': '#ID#f53d9331-6125-11eb-87ca...
# 15  [{'Price': '0.02432', 'PriceDate': '2019-01-23...
# 16  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 17  [{'PriceHistory': '#ID#f53d9336-6125-11eb-9748...
# 18  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 19  [{'Price': '0.0245', 'PriceDate': '2019-01-23T...
# 20  [{'PriceHistory': '#ID#f53da0ea-6125-11eb-a5f6...
# 21  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 22  [{'Price': '0.02461', 'PriceDate': '2019-01-23...
# 23  [{'PriceHistory': '#ID#f53da0ef-6125-11eb-9bde...
# 24  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 25  [{'PriceHistory': '#ID#f53da0f2-6125-11eb-b6b5...
# 26  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 27  [{'PriceHistory': '#ID#f53da0f5-6125-11eb-b7be...
# 28  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 29  [{'PriceHistory': '#ID#f53da0f8-6125-11eb-950e...
# 30  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 31  [{'PriceHistory': '#ID#f53da0fb-6125-11eb-ae28...
# 32  [{'Price': '0.02473', 'PriceDate': '2019-01-23...
# 33  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 34  [{'PriceHistory': '#ID#f53da100-6125-11eb-abbc...
# 35  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 36  [{'PriceHistory': '#ID#f53da103-6125-11eb-a68c...
# 37  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 38  [{'Price': '0.02558', 'PriceDate': '2019-01-23...
# 39  [{'PriceHistory': '#ID#f53da108-6125-11eb-b3e9...
# 40  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 41  [{'Price': '0.02593', 'PriceDate': '2019-01-23...
# 42  [{'PriceHistory': '#ID#f53da10d-6125-11eb-bbd1...
# 43  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...
# 44  [{'PriceHistory': '#ID#f53da110-6125-11eb-a61b...
# 45  [{'Price': '0.02588', 'PriceDate': '2019-01-23...
# 46  [{'PriceDate': '2019-01-23T00:00:00.000', 'Adj...

# %%
d1 = {'a': [1, 2, 3], 'b': [4, 5, 6]}
d2 = d1.copy()
def chnage_dict(di):
    di['a'] = 'xyz'
chnage_dict(d1)
print(id(d1))
print(id(d2))
# Out:
# 2376518330912
# 2376679334608
