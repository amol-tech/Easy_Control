# %% [markdown]
# ## XML Data Processing ##

# %%
from lxml import etree as ET
import os.path
from os import path
import shutil
import zipfile
import pandas as pd

dir_workspace = os.path.join(os.getcwd(),'workspace_Xml_Data_Processing')
dir_input = os.path.join(dir_workspace,'input')
dir_staging = os.path.join(dir_workspace,'staging')
dir_output = os.path.join(dir_workspace,'output')
print(dir_workspace)
# Out:
# D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing

# %% [markdown]
# #### Function : replace_error  ####
# * To replace the error in xml string before parsing

# %%
def replace_error(str_input):
    str_first = str_input[0:str_input.index('<Document xmlns')+9]
    str_part = str_input[str_input.index('<Document xmlns'):]
    str_last = str_part[str_part.index('>'):]
    str_output = str_first + str_last
    return str_output

# %% [markdown]
# #### Function : get_event_type  ####
# * To get the Event Type by parsing the xml string
# * It the tag 'CorpActnGnlInf/EvtTp' not found then return None

# %%
# Xml Parsing Code #
def get_event_type(str_xml):
    event_type = None
    if('<Document xmlns' in str_xml):
        str_xml = replace_error(str_xml)
        tree = ET.fromstring(str_xml)
        for elm_CorpActnGnlInf in tree.findall('.//CorpActnGnlInf'):
            for elm_EvtTp in elm_CorpActnGnlInf.findall('EvtTp'):
                for elm_Cd in elm_EvtTp.getchildren():
                    event_type = elm_Cd.text
                    break
    return event_type

# %%
def read_file(filename):
    with open(filename, 'r') as content_file:
        content = content_file.read()
        list_xml = content.split('<?xml version="1.0"?>')
        return list_xml[1:]

# %% [markdown]
# #### Function : get_file_info  ####
# * To get the counts of all event types for given file
# * If event type not found then return respective counts with label : 'NOT FOUND'

# %%
# File Reading Code #
def get_file_info(filename):
    list_xml = read_file(filename)
    list_event_type_found = [get_event_type(x) for x in list_xml if get_event_type(x) != None]
    count_event_type_not_found = len([x for x in list_xml if get_event_type(x) == None])
    
    dict_file_info = {}
    dict_file_info['FILE_NAME'] = filename.replace(dir_staging+'\dtc_cano.xml.','').replace('.txt','')
    for ev_type in list_event_type_found:
        dict_file_info[ev_type] = dict_file_info[ev_type] + 1 if(ev_type in dict_file_info.keys()) else 1
    dict_file_info['NOT_FOUND'] = count_event_type_not_found
    return dict_file_info

# %%
def group_by_event_type(filename,dict_event_type):
    list_xml = read_file(filename)
    
    for str_xml in list_xml:
        event_type = get_event_type(str_xml)
        if(event_type != None):
            if (not(event_type in dict_event_type.keys())):
                dict_event_type[event_type] = []
            dict_event_type[event_type].append(str_xml)

# %% [markdown]
# #### File Preperation  ####
# * Unzip all input files from input directory to staging directory

# %%
# Creating Staging Directory
if (path.exists(dir_staging)):
    shutil.rmtree(dir_staging)
os.mkdir(dir_staging)

for filename in sorted(os.listdir(dir_input)):
    filepath = os.path.join(dir_input, filename)
    with zipfile.ZipFile(filepath, 'r') as zip_ref:
        zip_ref.extractall(dir_staging)
        print('Extracted ... '+ filepath)
# Out:
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200701_185007.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200702_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200703_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200705_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200706_185006.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200707_185001.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200708_185008.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200709_185001.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200710_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200712_185004.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200713_185006.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200714_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200715_185005.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200716_185006.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200717_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200719_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200720_185004.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200721_185001.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200722_185002.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200723_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200724_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200726_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200727_185006.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200728_185004.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200729_185005.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200730_185003.txt.zip
# Extracted ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\input\dtc_cano.xml.20200731_185006.txt.zip

# %% [markdown]
# #### File Preocessing ####
# * Processed each file by calling function get_file_info and collect in the list

# %%
## Xml Processing Main Program
list_file_info = []
for filename in sorted(os.listdir(dir_staging)):
    filepath = os.path.join(dir_staging, filename)
    list_file_info.append(get_file_info(filepath))
    print('Processed ... '+filepath)

print('Successfully processed '+str(len(list_file_info))+ ' files.')
# Out:
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200701_185007.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200702_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200703_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200705_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200706_185006.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200707_185001.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200708_185008.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200709_185001.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200710_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200712_185004.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200713_185006.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200714_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200715_185005.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200716_185006.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200717_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200719_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200720_185004.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200721_185001.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200722_185002.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200723_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200724_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200726_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200727_185006.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200728_185004.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200729_185005.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200730_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200731_185006.txt
# Successfully processed 27 files.

# %% [markdown]
# #### Final Dashboard for Analysis ####

# %%
df = pd.DataFrame(list_file_info)
df.reset_index(drop=True, inplace=True)
df.to_csv(os.path.join(dir_workspace,'summary.csv'),index=False) 
df
# Out:
#      BIDS   BPUT   BRUP  CHAN  CONS   CONV  DETI  DFLT   DRAW  DTCH  ...  \
# 0    35.0  531.0    2.0  15.0  33.0  122.0   NaN   4.0  420.0   2.0  ...
# 1    32.0    5.0    2.0  20.0  15.0   51.0   1.0   NaN  853.0   NaN  ...
# 2     2.0   86.0    NaN   2.0  11.0   33.0   NaN   NaN  929.0   NaN  ...
# 3     NaN    NaN    NaN   1.0   NaN    NaN   NaN   NaN    NaN   NaN  ...
# 4     8.0   22.0   12.0  12.0   6.0   54.0   NaN   NaN  760.0   NaN  ...
# 5    20.0   16.0   26.0   5.0  12.0   71.0   NaN   NaN  459.0   NaN  ...
# 6    60.0    4.0    NaN  10.0   1.0   37.0   NaN   NaN  243.0   NaN  ...
# 7    17.0   17.0    2.0  10.0  10.0   46.0   NaN   1.0  289.0   1.0  ...
# 8    27.0   20.0    NaN  17.0  75.0   41.0   NaN   NaN  406.0   NaN  ...
# 9     NaN    NaN    NaN   1.0   NaN    NaN   NaN   NaN    NaN   NaN  ...
# 10   85.0   11.0    1.0  12.0  15.0   53.0   NaN   NaN  293.0   2.0  ...
# 11   42.0   18.0   11.0  11.0   2.0   63.0   NaN   NaN  375.0   1.0  ...
# 12   23.0   19.0  111.0  10.0   9.0   35.0   NaN   NaN  380.0   2.0  ...
# 13    NaN    6.0   59.0  11.0   5.0   27.0   NaN   NaN  285.0   3.0  ...
# 14   40.0    7.0    2.0  16.0  11.0   36.0   NaN   NaN  357.0   6.0  ...
# 15    NaN    NaN    NaN   1.0   NaN    NaN   NaN   NaN    NaN   NaN  ...
# 16   16.0   18.0    1.0  17.0   9.0   58.0   NaN   NaN  207.0   NaN  ...
# 17    9.0   10.0    6.0  20.0  15.0   37.0   NaN   NaN  285.0   1.0  ...
# 18    8.0   15.0    NaN  16.0   4.0   90.0   NaN   NaN  313.0   3.0  ...
# 19   27.0   15.0    4.0   8.0  17.0   59.0   NaN   NaN  518.0   2.0  ...
# 20   13.0    8.0    2.0  16.0   2.0   25.0   NaN   NaN  588.0   NaN  ...
# 21    NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN   NaN  ...
# 22  138.0   10.0    NaN   8.0   9.0   32.0   NaN   NaN  438.0   NaN  ...
# 23   29.0    7.0    8.0   9.0  28.0   53.0   NaN   NaN  378.0   NaN  ...
# 24   14.0    9.0   23.0  10.0   3.0   57.0   NaN   NaN  430.0   NaN  ...
# 25    6.0   20.0   11.0  14.0  48.0   69.0   NaN   NaN  549.0   NaN  ...
# 26    2.0   28.0    NaN  22.0  14.0   78.0   NaN   4.0  922.0   NaN  ...
#
#     NOOF  NOT_FOUND   OTHR    PDEF  PLAC    REDM  SPLF  SPLR  TEND  WRTH
# 0    NaN          0  208.0   135.0   2.0   378.0   NaN    26   3.0   9.0
# 1    NaN          0   57.0   190.0   NaN   397.0   NaN    30   6.0  10.0
# 2    NaN          0   66.0  1639.0   NaN  3946.0   NaN    10   NaN   7.0
# 3    NaN          0    9.0     NaN   NaN     NaN   NaN     1   NaN   2.0
# 4    2.0          0   10.0    81.0   NaN   345.0   NaN    23   6.0   5.0
# 5    NaN          0   14.0    75.0   2.0   390.0   NaN    27  10.0  11.0
# 6    1.0          0   45.0    93.0   1.0   362.0   NaN    29   6.0  16.0
# 7    NaN          0   45.0    78.0   1.0   337.0   NaN    23   2.0  17.0
# 8    3.0          0   33.0    82.0   NaN   261.0   NaN    27   9.0  17.0
# 9    NaN          0   10.0     NaN   NaN     NaN   NaN     1   NaN   2.0
# 10   2.0          0   23.0    72.0   2.0   662.0   NaN    25   5.0   8.0
# 11   NaN          0   11.0    27.0   3.0   426.0   NaN    33   1.0  18.0
# 12   7.0          0   14.0    26.0   3.0   392.0   NaN    33   4.0  10.0
# 13   2.0          0   17.0    10.0   NaN   194.0   NaN    25  18.0   6.0
# 14   2.0          0   12.0    72.0   1.0   753.0   2.0    25   3.0   6.0
# 15   NaN          0    NaN     NaN   NaN     1.0   NaN     1   1.0   NaN
# 16   NaN          0    5.0  1103.0   1.0  8060.0   NaN    22   4.0  10.0
# 17   NaN          0   26.0   395.0   NaN  2048.0   NaN    30   1.0  15.0
# 18   NaN          0    8.0    14.0   2.0   341.0   3.0    27   2.0   8.0
# 19   NaN          0    6.0     6.0   1.0   267.0   NaN    20   3.0   5.0
# 20   NaN          0   25.0    36.0   NaN   288.0   NaN    36   NaN  13.0
# 21   NaN          0    NaN     NaN   NaN    59.0   NaN     3   NaN   NaN
# 22   NaN          0   12.0    20.0   1.0   236.0   1.0    40   8.0  14.0
# 23   3.0          0   36.0    21.0   NaN   361.0   1.0    35   7.0  16.0
# 24   2.0          0   17.0    29.0   1.0   478.0   NaN    33   1.0  12.0
# 25   2.0          0   11.0    39.0   NaN   408.0   2.0    31   7.0  15.0
# 26   NaN          0   18.0   181.0   1.0  1786.0   NaN    30  11.0   9.0
#
# [27 rows x 27 columns]

# %%
## Xml Processing to Group base on Event Type
dict_event_type = {}
for filename in sorted(os.listdir(dir_staging)):
    filepath = os.path.join(dir_staging, filename)
    group_by_event_type(filepath,dict_event_type)
    print('Processed ... '+filepath)
# Out:
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200701_185007.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200702_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200703_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200705_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200706_185006.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200707_185001.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200708_185008.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200709_185001.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200710_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200712_185004.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200713_185006.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200714_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200715_185005.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200716_185006.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200717_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200719_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200720_185004.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200721_185001.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200722_185002.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200723_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200724_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200726_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200727_185006.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200728_185004.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200729_185005.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200730_185003.txt
# Processed ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\staging\dtc_cano.xml.20200731_185006.txt

# %%
# Creating Output Directory
if (path.exists(dir_output)):
    shutil.rmtree(dir_output)
os.mkdir(dir_output)

for event_type in dict_event_type:
    content = ''.join(dict_event_type[event_type])
    filepath = os.path.join(dir_output,'EventType_'+event_type+'.txt')
    textfile = open(filepath, 'w')
    textfile.write(content)
    textfile.close()
    print('Successfully created ... '+filepath)
# Out:
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_BIDS.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_EXRI.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_REDM.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_MRGR.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_OTHR.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_PLAC.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_SPLR.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_CHAN.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_DRAW.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_PDEF.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_MCAL.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_BPUT.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_EXWA.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_CONV.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_WRTH.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_CONS.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_EXOF.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_DTCH.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_DFLT.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_BRUP.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_LIQU.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_TEND.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_DETI.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_NOOF.txt
# Successfully created ... D:\GIT_Repositories\DevFactory\JupyterNoteBook_Dev\workspace_Xml_Data_Processing\output\EventType_SPLF.txt

# %%
import platform
platform.architecture()
# Out:
# ('64bit', 'WindowsPE')
