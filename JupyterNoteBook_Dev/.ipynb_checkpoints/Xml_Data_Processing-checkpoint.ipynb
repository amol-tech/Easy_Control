# %% [markdown]
# ## XML Data Processing ##

# %%
from lxml import etree as ET
import os.path
from os import path
import shutil
import zipfile
import pandas as pd

# %%
def replace_error(str_input):
    str_first = str_input[0:str_input.index('<Document xmlns')+9]
    str_part = str_input[str_input.index('<Document xmlns'):]
    str_last = str_part[str_part.index('>'):]
    str_output = str_first + str_last
    return str_output

# %%
# Xml Parsing Code #
def get_event_type(str_xml):
    event_type = None
    if('<Document xmlns' in str_xml):
        str_xml = replace_error(str_xml)
        tree = ET.fromstring(str_xml)
        for elm_CorpActnGnlInf in tree.findall('.//CorpActnGnlInf'):
            for elm_EvtTp in elm_CorpActnGnlInf.findall('EvtTp'):
                for elm_Cd in elm_EvtTp.getchildren():
                    event_type = elm_Cd.text
                    break
    #else:
        #print('xmlns not found')
    return event_type

# %%
# File Reading Code #
def get_file_info(filename):
    with open(filename, 'r') as content_file:
        content = content_file.read()
        list_xml = content.split('<?xml version="1.0"?>')
        list_xml = list_xml[1:]

    list_event_type_found = [get_event_type(x) for x in list_xml if get_event_type(x) != None]
    count_event_type_not_found = len([x for x in list_xml if get_event_type(x) == None])
    
    dict_file_info = {}
    dict_file_info['FILE_NAME'] = filename.replace('staging\dtc_cano.xml.','').replace('.txt','')
    for ev_type in list_event_type_found:
        dict_file_info[ev_type] = dict_file_info[ev_type] + 1 if(ev_type in dict_file_info.keys()) else 1
    dict_file_info['NOT_FOUND'] = count_event_type_not_found
    return dict_file_info

# %%
# Creating Staging Directory
if (path.exists('staging')):
    shutil.rmtree('staging')
os.mkdir('staging')

for filename in sorted(os.listdir('input')):
    filepath = os.path.join('input', filename)
    with zipfile.ZipFile(filepath, 'r') as zip_ref:
        zip_ref.extractall('staging')
        print('Extracted ... '+ filepath)
# Out:
# Extracted ... input\dtc_cano.xml.20200701_185007.txt.zip
# Extracted ... input\dtc_cano.xml.20200702_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200703_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200705_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200706_185006.txt.zip
# Extracted ... input\dtc_cano.xml.20200707_185001.txt.zip
# Extracted ... input\dtc_cano.xml.20200708_185008.txt.zip
# Extracted ... input\dtc_cano.xml.20200709_185001.txt.zip
# Extracted ... input\dtc_cano.xml.20200710_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200712_185004.txt.zip
# Extracted ... input\dtc_cano.xml.20200713_185006.txt.zip
# Extracted ... input\dtc_cano.xml.20200714_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200715_185005.txt.zip
# Extracted ... input\dtc_cano.xml.20200716_185006.txt.zip
# Extracted ... input\dtc_cano.xml.20200717_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200719_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200720_185004.txt.zip
# Extracted ... input\dtc_cano.xml.20200721_185001.txt.zip
# Extracted ... input\dtc_cano.xml.20200722_185002.txt.zip
# Extracted ... input\dtc_cano.xml.20200723_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200724_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200726_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200727_185006.txt.zip
# Extracted ... input\dtc_cano.xml.20200728_185004.txt.zip
# Extracted ... input\dtc_cano.xml.20200729_185005.txt.zip
# Extracted ... input\dtc_cano.xml.20200730_185003.txt.zip
# Extracted ... input\dtc_cano.xml.20200731_185006.txt.zip

# %%
## Xml Processing Main Program
list_file_info = []
for filename in sorted(os.listdir('staging')):
    filepath = os.path.join('staging', filename)
    list_file_info.append(get_file_info(filepath))
    print('Processed ... '+filepath)

print(len(list_file_info))
# Out:
# Processed ... staging\dtc_cano.xml.20200701_185007.txt
# Processed ... staging\dtc_cano.xml.20200702_185003.txt
# Processed ... staging\dtc_cano.xml.20200703_185003.txt
# Processed ... staging\dtc_cano.xml.20200705_185003.txt
# Processed ... staging\dtc_cano.xml.20200706_185006.txt
# Processed ... staging\dtc_cano.xml.20200707_185001.txt
# Processed ... staging\dtc_cano.xml.20200708_185008.txt
# Processed ... staging\dtc_cano.xml.20200709_185001.txt
# Processed ... staging\dtc_cano.xml.20200710_185003.txt
# Processed ... staging\dtc_cano.xml.20200712_185004.txt
# Processed ... staging\dtc_cano.xml.20200713_185006.txt
# Processed ... staging\dtc_cano.xml.20200714_185003.txt
# Processed ... staging\dtc_cano.xml.20200715_185005.txt
# Processed ... staging\dtc_cano.xml.20200716_185006.txt
# Processed ... staging\dtc_cano.xml.20200717_185003.txt
# Processed ... staging\dtc_cano.xml.20200719_185003.txt
# Processed ... staging\dtc_cano.xml.20200720_185004.txt
# Processed ... staging\dtc_cano.xml.20200721_185001.txt
# Processed ... staging\dtc_cano.xml.20200722_185002.txt
# Processed ... staging\dtc_cano.xml.20200723_185003.txt
# Processed ... staging\dtc_cano.xml.20200724_185003.txt
# Processed ... staging\dtc_cano.xml.20200726_185003.txt
# Processed ... staging\dtc_cano.xml.20200727_185006.txt
# Processed ... staging\dtc_cano.xml.20200728_185004.txt
# Processed ... staging\dtc_cano.xml.20200729_185005.txt
# Processed ... staging\dtc_cano.xml.20200730_185003.txt
# Processed ... staging\dtc_cano.xml.20200731_185006.txt
# 27

# %%
df = pd.DataFrame(list_file_info)
df
# Out:
#                                FILE_NAME   BIDS  EXRI    REDM  MRGR   OTHR  \
# 0   staging\dtc_cano.xml.20200701_185007   35.0   2.0   378.0  30.0  208.0
# 1   staging\dtc_cano.xml.20200702_185003   32.0   2.0   397.0  37.0   57.0
# 2   staging\dtc_cano.xml.20200703_185003    2.0   4.0  3946.0   4.0   66.0
# 3   staging\dtc_cano.xml.20200705_185003    NaN   NaN     NaN   4.0    9.0
# 4   staging\dtc_cano.xml.20200706_185006    8.0   2.0   345.0  12.0   10.0
# 5   staging\dtc_cano.xml.20200707_185001   20.0   3.0   390.0  12.0   14.0
# 6   staging\dtc_cano.xml.20200708_185008   60.0   6.0   362.0  20.0   45.0
# 7   staging\dtc_cano.xml.20200709_185001   17.0   1.0   337.0  21.0   45.0
# 8   staging\dtc_cano.xml.20200710_185003   27.0   1.0   261.0  11.0   33.0
# 9   staging\dtc_cano.xml.20200712_185004    NaN   NaN     NaN   3.0   10.0
# 10  staging\dtc_cano.xml.20200713_185006   85.0   NaN   662.0  12.0   23.0
# 11  staging\dtc_cano.xml.20200714_185003   42.0   NaN   426.0   5.0   11.0
# 12  staging\dtc_cano.xml.20200715_185005   23.0   4.0   392.0   8.0   14.0
# 13  staging\dtc_cano.xml.20200716_185006    NaN   NaN   194.0  15.0   17.0
# 14  staging\dtc_cano.xml.20200717_185003   40.0   NaN   753.0   9.0   12.0
# 15  staging\dtc_cano.xml.20200719_185003    NaN   NaN     1.0   NaN    NaN
# 16  staging\dtc_cano.xml.20200720_185004   16.0   8.0  8060.0  17.0    5.0
# 17  staging\dtc_cano.xml.20200721_185001    9.0   1.0  2048.0  19.0   26.0
# 18  staging\dtc_cano.xml.20200722_185002    8.0   9.0   341.0  20.0    8.0
# 19  staging\dtc_cano.xml.20200723_185003   27.0  11.0   267.0   1.0    6.0
# 20  staging\dtc_cano.xml.20200724_185003   13.0   6.0   288.0   7.0   25.0
# 21  staging\dtc_cano.xml.20200726_185003    NaN   NaN    59.0   NaN    NaN
# 22  staging\dtc_cano.xml.20200727_185006  138.0   7.0   236.0  11.0   12.0
# 23  staging\dtc_cano.xml.20200728_185004   29.0  11.0   361.0   8.0   36.0
# 24  staging\dtc_cano.xml.20200729_185005   14.0  16.0   478.0  14.0   17.0
# 25  staging\dtc_cano.xml.20200730_185003    6.0   3.0   408.0   9.0   11.0
# 26  staging\dtc_cano.xml.20200731_185006    2.0   8.0  1786.0   9.0   18.0
#
#     PLAC  SPLR  CHAN   DRAW  ...   EXOF  DTCH  DFLT   BRUP  LIQU  TEND  \
# 0    2.0    26  15.0  420.0  ...   35.0   2.0   4.0    2.0   3.0   3.0
# 1    NaN    30  20.0  853.0  ...  113.0   NaN   NaN    2.0   1.0   6.0
# 2    NaN    10   2.0  929.0  ...    8.0   NaN   NaN    NaN   NaN   NaN
# 3    NaN     1   1.0    NaN  ...    1.0   NaN   NaN    NaN   NaN   NaN
# 4    NaN    23  12.0  760.0  ...  107.0   NaN   NaN   12.0   1.0   6.0
# 5    2.0    27   5.0  459.0  ...  100.0   NaN   NaN   26.0   3.0  10.0
# 6    1.0    29  10.0  243.0  ...  164.0   NaN   NaN    NaN   2.0   6.0
# 7    1.0    23  10.0  289.0  ...   61.0   1.0   1.0    2.0   5.0   2.0
# 8    NaN    27  17.0  406.0  ...   90.0   NaN   NaN    NaN   NaN   9.0
# 9    NaN     1   1.0    NaN  ...    5.0   NaN   NaN    NaN   NaN   NaN
# 10   2.0    25  12.0  293.0  ...   84.0   2.0   NaN    1.0   NaN   5.0
# 11   3.0    33  11.0  375.0  ...  243.0   1.0   NaN   11.0   NaN   1.0
# 12   3.0    33  10.0  380.0  ...   80.0   2.0   NaN  111.0   1.0   4.0
# 13   NaN    25  11.0  285.0  ...   82.0   3.0   NaN   59.0   2.0  18.0
# 14   1.0    25  16.0  357.0  ...  178.0   6.0   NaN    2.0   NaN   3.0
# 15   NaN     1   1.0    NaN  ...    9.0   NaN   NaN    NaN   NaN   1.0
# 16   1.0    22  17.0  207.0  ...   65.0   NaN   NaN    1.0   4.0   4.0
# 17   NaN    30  20.0  285.0  ...   38.0   1.0   NaN    6.0   1.0   1.0
# 18   2.0    27  16.0  313.0  ...   84.0   3.0   NaN    NaN   NaN   2.0
# 19   1.0    20   8.0  518.0  ...   26.0   2.0   NaN    4.0   NaN   3.0
# 20   NaN    36  16.0  588.0  ...   24.0   NaN   NaN    2.0   1.0   NaN
# 21   NaN     3   NaN    NaN  ...    NaN   NaN   NaN    NaN   NaN   NaN
# 22   1.0    40   8.0  438.0  ...   86.0   NaN   NaN    NaN   NaN   8.0
# 23   NaN    35   9.0  378.0  ...  119.0   NaN   NaN    8.0   6.0   7.0
# 24   1.0    33  10.0  430.0  ...   63.0   NaN   NaN   23.0   1.0   1.0
# 25   NaN    31  14.0  549.0  ...   91.0   NaN   NaN   11.0   2.0   7.0
# 26   1.0    30  22.0  922.0  ...  121.0   NaN   4.0    NaN   2.0  11.0
#
#     NOT_FOUND  DETI  NOOF  SPLF
# 0           0   NaN   NaN   NaN
# 1           0   1.0   NaN   NaN
# 2           0   NaN   NaN   NaN
# 3           0   NaN   NaN   NaN
# 4           0   NaN   2.0   NaN
# 5           0   NaN   NaN   NaN
# 6           0   NaN   1.0   NaN
# 7           0   NaN   NaN   NaN
# 8           0   NaN   3.0   NaN
# 9           0   NaN   NaN   NaN
# 10          0   NaN   2.0   NaN
# 11          0   NaN   NaN   NaN
# 12          0   NaN   7.0   NaN
# 13          0   NaN   2.0   NaN
# 14          0   NaN   2.0   2.0
# 15          0   NaN   NaN   NaN
# 16          0   NaN   NaN   NaN
# 17          0   NaN   NaN   NaN
# 18          0   NaN   NaN   3.0
# 19          0   NaN   NaN   NaN
# 20          0   NaN   NaN   NaN
# 21          0   NaN   NaN   NaN
# 22          0   NaN   NaN   1.0
# 23          0   NaN   3.0   1.0
# 24          0   NaN   2.0   NaN
# 25          0   NaN   2.0   2.0
# 26          0   NaN   NaN   NaN
#
# [27 rows x 27 columns]

# %%
import pandas as pd
dict1 = {'name':'abc','count':12}
dict2 = {'name':'abc','sum':80}
list_dic = [dict1,dict2]
df = pd.DataFrame(list_dic)
df
# Out:
#   name  count   sum
# 0  abc   12.0   NaN
# 1  abc    NaN  80.0

# %%
str_ex = '<AppHdr> <AppHdr> <Document xmlns="urn:iso:std:iso:20022:tech:xsd:seev.039.002.09" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"> and furtehr'
replace_error(str_ex)
# Out:
# '<AppHdr> <AppHdr> <Documen> and furtehr'
